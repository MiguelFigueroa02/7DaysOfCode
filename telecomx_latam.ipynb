# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelFigueroa02/7DaysOfCode/blob/main/telecomx_latam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %% [markdown]
# ## Conociendo los datos

# %% [markdown]
# ### Carga de la información

# %%
import pandas as pd

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
